# %%
#Modified Audio Search engine

# %%
from scipy import fft, arange, signal
from scipy.special import logit, expit
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
import os
from ttictoc import TicToc

# %%
def main():
    """Main function"""
    pass

# %%
def read_file(path):
    """
    Reads the audio .wav file and returns the sample rate and data contents of the file.
    """
    sr, signal = wavfile.read(path)
    return sr, signal[:,0]

# %%
sr, signal = read_file("Animals, batch test 1.wav")

# %%
sr_1, signal_1 = read_file("Animals Live Test.wav")

# %%
sr, sr_1
# Out:
# (44100, 44100)

# %%
signal.shape
# Out:
# (941056,)

# %%
signal_1.shape
# Out:
# (8664064,)

# %%
plt.figure(figsize=(20,10))
plt.plot(signal_1)

# %%
len(signal)/sr_1
# Out:
# 21.339138321995463

# %%
X_axis = len(signal)//sr_1
fourier = fft(signal)

# %%
fourier.shape
# Out:
# (941056,)

# %%
val = fourier.mean()

# %%
val.imag
# Out:
# 2.0268173549847193e-12

# %%
val
# Out:
# (-4.750353175745436e-13+2.0268173549847193e-12j)

# %%
Amplitude = (val.real**2 + val.imag**2)**0.5
phase_shift = np.arctan(val.imag/val.real)*(180/np.pi)

# %%
Amplitude, phase_shift
# Out:
# (2.081741372843995e-12, -76.80938928779315)

# %%
np.cos(np.deg2rad(phase_shift))
# Out:
# 0.22819132278932822

# %%
np.deg2rad(phase_shift)
# Out:
# -1.340576739518053

# %%
frequency = sr
omega = 2*np.pi*frequency

# %%
omega
# Out:
# 277088.47204661975

# %%
def generate_time_domain_graph(frequency, fourier_transformation):

# %%
len(signal_1)/sr_1
# Out:
# 196.46403628117915

# %%
plt.plot(fft(signal_1)[:100])
# Out:
# C:\Users\qasim\Anaconda3\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(signal_1[:50000])

# %%
_, data = read_file("Marvin Gaye - Lets get it on.wav")

# %%
plt.plot(data[0:50000])
